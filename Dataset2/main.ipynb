# %%
import pandas as pd
import numpy as np


df = pd.read_csv("Titanic-Dataset.csv.xls")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum() #checking for missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.drop(columns=['Cabin'], inplace=True) #too many missing values

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
print("Missing values after:\n", df.isnull().sum())
# Out:
# Missing values after:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# ...

# %%
#Survival count
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
df['Survived'].value_counts().plot(kind='bar', color=['salmon', 'lightblue'])
plt.title("Survival Count (0 = Died, 1 = Survived)")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()

# %%
# survival by gender
plt.figure(figsize=(6,4))
df.groupby("Sex")['Survived'].mean().plot(kind='bar', color=['orange','purple'])
plt.title("Survival Rate by Gender")
plt.ylabel("Survival Rate")
plt.show()

# %%
# Survival by Passenger class 
plt.figure(figsize=(6,4))
df.groupby("Pclass")['Survived'].mean().plot(kind='bar', color=['gold','silver','brown'])
plt.title("Survival Rate by Passenger Class")
plt.ylabel("Survival Rate")
plt.show()

# %%
# Age distribution 
plt.figure(figsize=(8,5))
df[df['Survived']==1]['Age'].plot.hist(bins=30, alpha=0.6, label='Survived')
df[df['Survived']==0]['Age'].plot.hist(bins=30, alpha=0.6, label='Died')
plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
# Fare Distribution
plt.figure(figsize=(8,5))
df[df['Survived']==1]['Fare'].plot.hist(bins=40, alpha=0.6, label='Survived')
df[df['Survived']==0]['Fare'].plot.hist(bins=40, alpha=0.6, label='Died')
plt.title("Fare Distribution by Survival")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# AIRQUALITY DATASET

# %%
df_air = pd.read_csv("AirQualityUCI.csv", sep=';', decimal=',', low_memory=False)
df_air
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df_air.head(10)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# 5  10/03/2004  23.00.00     1.2       1197.0      38.0       4.7
# 6  11/03/2004  00.00.00     1.2       1185.0      31.0       3.6
# 7  11/03/2004  01.00.00     1.0       1136.0      31.0       3.3
# 8  11/03/2004  02.00.00     0.9       1094.0      24.0       2.3
# 9  11/03/2004  03.00.00     0.6       1010.0      19.0       1.7
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# ...

# %%
df_air.isnull().sum() #checking for missing values
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# dropping unamed columns 
if "Unnamed: 15" in df_air.columns:
    df_air.drop(columns=["Unnamed: 15"], inplace=True)
if "Unnamed: 16" in df_air.columns:
    df_air.drop(columns=["Unnamed: 16"], inplace=True)

# %%
df_air.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
df_air.fillna(df_air.median(numeric_only=True), inplace=True)  #filling missing values

# %%
df_air.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
#Histogram of CO concentration
df_air['CO(GT)'].plot.hist(bins=40, color="skyblue", edgecolor="black")
plt.title("Histogram of CO Concentration")
plt.xlabel("CO (GT)")
plt.show()

# %%
#boxplot of No2
df_air['NO2(GT)'].plot.box()
plt.title("Boxplot of NO2 Concentration")
plt.show()

# %%
plt.scatter(df_air['CO(GT)'], df_air['NO2(GT)'], alpha=0.5)
plt.title("CO vs NO2")
plt.xlabel("CO (GT)")
plt.ylabel("NO2 (GT)")
plt.show()
